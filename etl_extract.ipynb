# %%
import pandas as pd
from faker import Faker
import random
from datetime import datetime, timedelta

# Initialize Faker
fake = Faker()

# Generate 100 records
data = []
start_date = datetime(2025, 1, 1)
for i in range(100):
    record = {
        'transaction_id': i + 1,
        'date': start_date + timedelta(days=random.randint(0, 90)),
        'product': fake.word().capitalize() + " " + random.choice(['Laptop', 'Phone', 'Tablet']),
        'quantity': random.randint(1, 10),
        'price': round(random.uniform(100, 2000), 2),
        'customer_name': fake.name()
    }
    data.append(record)

# Create DataFrame and save to CSV
df = pd.DataFrame(data)
df.to_csv('custom_data.csv', index=False)
print("Dataset generated and saved as custom_data.csv")
# Out:
# Dataset generated and saved as custom_data.csv

# %%
# Rename the 'date' column to 'last_updated'
df = df.rename(columns={'date': 'last_updated'})

# Save the updated dataset back to the CSV file
df.to_csv("custom_data.csv", index=False)
print(df.columns)
# Out:
# Index(['transaction_id', 'last_updated', 'product', 'quantity', 'price',
#        'customer_name'],
#       dtype='object')

# %%
# FULL EXTRACTION
df_full = pd.read_csv("custom_data.csv", parse_dates=["last_updated"])
print(f"Pulled {len(df_full)} rows via full extraction.")
df_full.head()
# Out:
# Pulled 100 rows via full extraction.
#    transaction_id last_updated          product  quantity    price  \
# 0               1   2025-02-22    Father Laptop         9   966.80
# 1               2   2025-02-12     Behind Phone         5  1313.42
# 2               3   2025-03-19  Political Phone         8  1560.93
# 3               4   2025-03-13    Answer Laptop         4   134.72
# 4               5   2025-01-03      Mouth Phone         6   649.93
#
#      customer_name
# 0      Andre Jones
# 1      Roberta Lee
# 2  Anthony Andrews
# 3       Anna Kelly
# 4    Ashley Gentry

# %%
# Set initial last extraction time (e.g., halfway through the data range)
with open("last_extraction.txt", "w") as f:
    f.write("2025-02-28 10:03:00")

# %%
# INCREMENTAL EXTRACTION
with open("last_extraction.txt", "r") as f:
    last_extraction = f.read().strip()
df = pd.read_csv("custom_data.csv", parse_dates=["last_updated"])
last_extraction_time = pd.to_datetime(last_extraction)
df_incremental = df[df['last_updated'] > last_extraction_time]
print(f"Pulled {len(df_incremental)} new/updated rows since {last_extraction}.")
df_incremental.head()
# Out:
# Pulled 41 new/updated rows since 2025-02-28 10:03:00.
#     transaction_id last_updated           product  quantity    price  \
# 2                3   2025-03-19   Political Phone         8  1560.93
# 3                4   2025-03-13     Answer Laptop         4   134.72
# 6                7   2025-03-03   Remember Tablet         5  1829.04
# 7                8   2025-03-01  Represent Tablet         2  1487.61
# 11              12   2025-03-13    Western Laptop         9   731.28
#
#       customer_name
# 2   Anthony Andrews
# 3        Anna Kelly
# 6   Brenda Reynolds
# 7       Ryan Prince
# 11     David Bishop

# %%
# Get the most recent update
new_checkpoint = df['last_updated'].max()
# Save it
with open("last_extraction.txt", "w") as f:
    f.write(new_checkpoint.isoformat())
print(f"Updated last_extraction.txt to {new_checkpoint}")
# Out:
# Updated last_extraction.txt to 2025-04-01 00:00:00

# %% [markdown]
# LAB 5
# Cleaning the data

# %%
# loading the data
df_full = pd.read_csv("custom_data.csv", parse_dates=["last_updated"])

# %%
# Checking how many duplicate rows exist
duplicates = df_full.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

# Show count of missing values in each column
print(df_full.isnull().sum())
# Out:
# Number of duplicate rows: 0
# transaction_id    0
# last_updated      0
# product           0
# quantity          0
# price             0
# customer_name     0
# dtype: int64

# %% [markdown]
# they are no duplicated rows or missing values in the dataset

# %% [markdown]
# Enrichment of the data

# %%
#Adding a new column called total price which is quantity * price 
df_full['total_price'] = df_full['quantity'] * df_full['price']

# Classifying the customer type to VIP(>1000) and Regular(<1000) according to the price paid for products
df_full['customer_type'] = df_full['price'].apply(lambda x: 'VIP' if x > 1000 else 'Regular')

# loading the dataset to show the new columns created and the customer type
df_full.head(5)
# Out:
#    transaction_id last_updated          product  quantity    price  \
# 0               1   2025-02-22    Father Laptop         9   966.80
# 1               2   2025-02-12     Behind Phone         5  1313.42
# 2               3   2025-03-19  Political Phone         8  1560.93
# 3               4   2025-03-13    Answer Laptop         4   134.72
# 4               5   2025-01-03      Mouth Phone         6   649.93
#
#      customer_name  total_price customer_type
# 0      Andre Jones      8701.20       Regular
# 1      Roberta Lee      6567.10           VIP
# 2  Anthony Andrews     12487.44           VIP
# 3       Anna Kelly       538.88       Regular
# 4    Ashley Gentry      3899.58       Regular

# %% [markdown]
# Structural Transformation

# %%
# checking the data types of all columns to ensure they are in the right type
df_full.dtypes
# Out:
# transaction_id             int64
# last_updated      datetime64[ns]
# product                   object
# quantity                   int64
# price                    float64
# customer_name             object
# total_price              float64
# customer_type             object
# dtype: object

# %% [markdown]
# all the columns are of the correct data type hence no need to change anything

# %% [markdown]
# Saving the transformed full dataset

# %%
df_full.to_csv("transformed_full.csv", index=False)

# %% [markdown]
# Incremented data

# %%
#loading the data
df_incremental.to_csv("incremented_data.csv", index=False) # saving the incremented data into its own csv file

tf= pd.read_csv("incremented_data.csv", parse_dates=["last_updated"]) # reading the new csv file
tf
# Out:
#     transaction_id last_updated            product  quantity    price  \
# 0                3   2025-03-19    Political Phone         8  1560.93
# 1                4   2025-03-13      Answer Laptop         4   134.72
# 2                7   2025-03-03    Remember Tablet         5  1829.04
# 3                8   2025-03-01   Represent Tablet         2  1487.61
# 4               12   2025-03-13     Western Laptop         9   731.28
# 5               14   2025-03-18      Imagine Phone         2   658.90
# 6               15   2025-03-03        They Laptop         3  1320.13
# 7               17   2025-03-24  Collection Tablet         2  1986.05
# 8               18   2025-03-22         Pay Laptop        10   178.35
# 9               19   2025-03-11      Science Phone         7   263.79
# 10              20   2025-03-10     Protect Laptop         7   226.12
# 11              21   2025-03-31       Pretty Phone         4  1610.99
# 12              23   2025-03-25          Bar Phone         8   367.29
# 13              24   2025-03-19        Wind Laptop         9   485.28
# 14              28   2025-03-16    Possible Tablet         6  1123.67
# 15              29   2025-03-16         Nice Phone         2  1407.78
# 16              32   2025-03-15         Sit Laptop         2  1660.00
# 17              37   2025-03-25       Think Tablet         9   665.91
# 18              41   2025-03-02        City Tablet         6  1092.13
# 19              42   2025-03-09       Speech Phone         6  1660.54
# 20              50   2025-03-26        Take Laptop         5  1633.47
# 21              51   2025-03-28          Ask Phone         9   680.27
# 22              55   2025-03-02         Seem Phone         4  1227.47
# 23              57   2025-03-22         Son Tablet        10  1134.93
# 24              61   2025-03-21       Method Phone         4   438.64
# 25              64   2025-03-31     Southern Phone        10  1826.71
# 26              65   2025-03-28        Note Laptop         2   305.65
# 27              66   2025-03-25         Few Tablet         4   471.69
# 28              68   2025-03-10         Ago Laptop         9   205.78
# 29              72   2025-03-05      Purpose Phone         8  1953.65
# 30              73   2025-03-29         Else Phone        10   150.06
# 31              78   2025-03-01         Cut Tablet        10   597.60
# 32              79   2025-04-01       Course Phone         8   320.87
# 33              80   2025-03-14     Receive Laptop         1   543.79
# 34              83   2025-03-18         Fine Phone         3  1569.93
# 35              87   2025-03-14   Community Laptop         3   916.59
# 36              92   2025-03-21          Arm Phone         6  1553.35
# 37              93   2025-03-24       Ahead Tablet         5  1697.01
# 38              94   2025-03-13         Key Laptop         7  1722.67
# 39              95   2025-03-26          New Phone         3  1950.03
# 40              96   2025-03-14         Dog Tablet         3  1094.51
#
#            customer_name
# 0        Anthony Andrews
# 1             Anna Kelly
# 2        Brenda Reynolds
# 3            Ryan Prince
# 4           David Bishop
# 5              Mary Vega
# 6       Christina Foster
# 7           David Flores
# 8   Dr. Bruce Richardson
# 9          Edward Miller
# 10            Alan Mason
# 11            Zoe Larson
# 12       Nicholas Taylor
# 13         Robert Walker
# 14          Leslie Reyes
# 15       Isabella Hanson
# 16        Felicia Gordon
# 17         Brian Hancock
# 18       Vicki Rodriguez
# 19          Audrey Smith
# 20            Jason Hahn
# 21     Travis Washington
# 22           Dawn Kelley
# 23          Wendy Taylor
# 24          Jamie Bailey
# 25        Kevin Sandoval
# 26          Sara Johnson
# 27    Jeffrey Livingston
# 28             Mary Ball
# 29       Patricia Snyder
# 30            Eric Adams
# 31          Anita Obrien
# 32          Nicole Davis
# 33       Melissa Nichols
# 34       Victoria Bowman
# 35         Carolyn Allen
# 36           Jason Young
# 37            Emma Burke
# 38        Michelle Brown
# 39           Kara Wright
# 40           Wanda Sloan

# %%
# cleaning the incremented data

# Checking how many duplicate rows exist
duplicates = tf.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

# Show count of missing values in each column
print(tf.isnull().sum())
# Out:
# Number of duplicate rows: 0
# transaction_id    0
# last_updated      0
# product           0
# quantity          0
# price             0
# customer_name     0
# dtype: int64

# %% [markdown]
# Enrichment

# %%
#Adding a new column called total price which is quantity * price 
tf['total_price'] = tf['quantity'] * tf['price']

# Classifying the customer type to VIP(>1000) and Regular(<1000) according to the price paid for products
tf['customer_type'] = tf['price'].apply(lambda x: 'VIP' if x > 1000 else 'Regular')

# loading the dataset to show the new columns created and the customer type
tf.head(5)
# Out:
#    transaction_id last_updated           product  quantity    price  \
# 0               3   2025-03-19   Political Phone         8  1560.93
# 1               4   2025-03-13     Answer Laptop         4   134.72
# 2               7   2025-03-03   Remember Tablet         5  1829.04
# 3               8   2025-03-01  Represent Tablet         2  1487.61
# 4              12   2025-03-13    Western Laptop         9   731.28
#
#      customer_name  total_price customer_type
# 0  Anthony Andrews     12487.44           VIP
# 1       Anna Kelly       538.88       Regular
# 2  Brenda Reynolds      9145.20           VIP
# 3      Ryan Prince      2975.22           VIP
# 4     David Bishop      6581.52       Regular

# %% [markdown]
# Structural transformation

# %%
# checking the data types of all columns to ensure they are in the right type
tf.dtypes
# Out:
# transaction_id             int64
# last_updated      datetime64[ns]
# product                   object
# quantity                   int64
# price                    float64
# customer_name             object
# total_price              float64
# customer_type             object
# dtype: object

# %%
# saving the transformed incremental dataset
tf.to_csv("transformed_incremental.csv", index=False)
